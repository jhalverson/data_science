# %% [markdown]
# # Jonathan Halverson
# # Wednesday, July 13, 2016
# # SQL/Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('halverson')

# %%
df = pd.read_csv('FL_insurance_sample.csv')
df.head(3).transpose()
# Out:
#                               0            1            2
# policyID                 119736       448094       206893
# statecode                    FL           FL           FL
# county              CLAY COUNTY  CLAY COUNTY  CLAY COUNTY
# eq_site_limit            498960  1.32238e+06       190724
# hu_site_limit            498960  1.32238e+06       190724
# fl_site_limit            498960  1.32238e+06       190724
# fr_site_limit            498960  1.32238e+06       190724
# tiv_2011                 498960  1.32238e+06       190724
# tiv_2012                 792149  1.43816e+06       192477
# eq_site_deductible            0            0            0
# hu_site_deductible       9979.2            0            0
# fl_site_deductible            0            0            0
# fr_site_deductible            0            0            0
# point_latitude          30.1023      30.0639      30.0896
# point_longitude        -81.7118     -81.7077     -81.7005
# line                Residential  Residential  Residential
# construction            Masonry      Masonry         Wood
# point_granularity             1            3            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36634 entries, 0 to 36633
# Data columns (total 18 columns):
# policyID              36634 non-null int64
# statecode             36634 non-null object
# county                36634 non-null object
# eq_site_limit         36634 non-null float64
# hu_site_limit         36634 non-null float64
# fl_site_limit         36634 non-null float64
# fr_site_limit         36634 non-null float64
# tiv_2011              36634 non-null float64
# tiv_2012              36634 non-null float64
# eq_site_deductible    36634 non-null float64
# hu_site_deductible    36634 non-null float64
# fl_site_deductible    36634 non-null float64
# fr_site_deductible    36634 non-null int64
# point_latitude        36634 non-null float64
# point_longitude       36634 non-null float64
# line                  36634 non-null object
# construction          36634 non-null object
# point_granularity     36634 non-null int64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 5.0+ MB

# %%
#select avg(point_latitude), min(point_latitude), max(point_latitude), stddev(point_latitude) from insur;
df.describe()
# Out:
#             policyID  eq_site_limit  hu_site_limit  fl_site_limit  \
# count   36634.000000   3.663400e+04   3.663400e+04   3.663400e+04
# mean   548661.937189   7.314780e+05   2.074348e+06   6.646009e+05
# std    259912.926494   1.752300e+07   1.964150e+07   1.746114e+07
# min    100074.000000   0.000000e+00   0.000000e+00   0.000000e+00
# 25%    323647.750000   0.000000e+00   4.248106e+04   0.000000e+00
# 50%    548525.000000   0.000000e+00   1.926911e+05   0.000000e+00
# 75%    774252.000000   0.000000e+00   9.163381e+05   0.000000e+00
# max    999971.000000   2.160000e+09   2.160000e+09   2.160000e+09
#
#        fr_site_limit      tiv_2011      tiv_2012  eq_site_deductible  \
# count   3.663400e+04  3.663400e+04  3.663400e+04        3.663400e+04
# mean    9.911724e+05  2.172875e+06  2.571004e+06        7.787908e+02
# std     1.767178e+07  2.015015e+07  2.036777e+07        4.787979e+04
# min     0.000000e+00  9.000000e+01  7.337000e+01        0.000000e+00
# 25%     0.000000e+00  4.562415e+04  5.401351e+04        0.000000e+00
# 50%     0.000000e+00  2.021051e+05  2.416310e+05        0.000000e+00
# 75%     5.741010e+04  9.465821e+05  1.128871e+06        0.000000e+00
# max     2.160000e+09  2.160000e+09  1.701000e+09        6.273765e+06
#
#        hu_site_deductible  fl_site_deductible  fr_site_deductible  \
# count        3.663400e+04        36634.000000        36634.000000
# mean         7.037985e+03          192.453210           26.483594
# std          9.582593e+04         8037.713716         4702.740932
# min          0.000000e+00            0.000000            0.000000
# 25%          0.000000e+00            0.000000            0.000000
# 50%          0.000000e+00            0.000000            0.000000
# 75%          0.000000e+00            0.000000            0.000000
# max          7.380000e+06       450000.000000       900000.000000
#
#        point_latitude  point_longitude  point_granularity
# count    36634.000000     36634.000000       36634.000000
# mean        28.087477       -81.903565           1.640907
# std          1.647734         1.809066           1.070561
# min         24.547514       -87.447290           1.000000
# 25%         26.471996       -82.439331           1.000000
# 50%         28.057077       -81.585700           1.000000
# 75%         29.623005       -80.372910           3.000000
# max         30.989820       -80.033257           7.000000

# %%
# need periscope or something to make plots in SQL
plt.plot(df.point_longitude, df.point_latitude, '.')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Florida insurance samples')

# %%
# select county, count(county) from insur group by county order by count(county) desc;
df.county.value_counts()
# Out:
# MIAMI DADE COUNTY      4315
# BROWARD COUNTY         3193
# PALM BEACH COUNTY      2791
# DUVAL COUNTY           1894
# ORANGE COUNTY          1811
# PINELLAS COUNTY        1774
# POLK COUNTY            1629
# VOLUSIA COUNTY         1367
# HILLSBOROUGH COUNTY    1166
# MARION COUNTY          1138
# OKALOOSA COUNTY        1115
# SEMINOLE COUNTY        1100
# ALACHUA COUNTY          973
# BREVARD COUNTY          872
# SANTA ROSA COUNTY       856
# PASCO COUNTY            790
# COLLIER COUNTY          787
# LEE COUNTY              678
# ST  JOHNS COUNTY        657
# MANATEE COUNTY          518
# ESCAMBIA COUNTY         494
# SARASOTA COUNTY         417
# CHARLOTTE COUNTY        414
# BAY COUNTY              403
# CITRUS COUNTY           384
# INDIAN RIVER COUNTY     380
# HIGHLANDS COUNTY        369
# CLAY COUNTY             363
# WALTON COUNTY           288
# PUTNAM COUNTY           268
#                        ...
# MONROE COUNTY           152
# NASSAU COUNTY           135
# LEVY COUNTY             126
# COLUMBIA COUNTY         125
# HERNANDO COUNTY         120
# WASHINGTON COUNTY       116
# TAYLOR COUNTY           113
# MARTIN COUNTY           109
# DESOTO COUNTY           108
# WAKULLA COUNTY           85
# HARDEE COUNTY            81
# MADISON COUNTY           81
# HENDRY COUNTY            74
# GULF COUNTY              72
# BAKER COUNTY             70
# CALHOUN COUNTY           68
# LAFAYETTE COUNTY         68
# JEFFERSON COUNTY         57
# DIXIE COUNTY             40
# HOLMES COUNTY            40
# GILCHRIST COUNTY         39
# FRANKLIN COUNTY          37
# LIBERTY COUNTY           36
# HAMILTON COUNTY          35
# BRADFORD COUNTY          31
# GLADES COUNTY            22
# UNION COUNTY             15
# OSCEOLA COUNTY            1
# North Fort Myers          1
# Orlando                   1
# Name: county, dtype: int64

# %%
df.construction.value_counts()
# Out:
# Wood                   21581
# Masonry                 9257
# Reinforced Masonry      4225
# Reinforced Concrete     1299
# Steel Frame              272
# Name: construction, dtype: int64

# %%
# the average total insured value increase from 2011 to 2012 by construction material
df['tiv_diff'] = df.tiv_2012 - df.tiv_2011

# %%
#select construction, avg(tiv_2012 - tiv_2011) from insur group by construction;
df.groupby('construction').agg({'tiv_diff':np.mean})
# Out:
#                          tiv_diff
# construction
# Masonry              1.811178e+05
# Reinforced Concrete  3.561251e+06
# Reinforced Masonry   7.965161e+05
# Steel Frame          1.650838e+07
# Wood                 1.977795e+04

# %%
# select policy_id, tiv_2011, tiv_2012, construction from insur where construction='wood' and (tiv_2012 - tiv_2011 > 250000.0);
df[['policyID', 'tiv_2011', 'tiv_2012', 'construction']][(df.construction=='Wood') & (df.tiv_diff > 250000.0)].sort_values('policyID')
# Out:
#        policyID   tiv_2011   tiv_2012 construction
# 8486     118775  349906.50  600607.51         Wood
# 36316    222173  355414.25  649046.12         Wood
# 34689    226317  303766.20  566463.21         Wood
# 26039    307614  342198.00  605323.62         Wood
# 24689    321321  293965.28  545011.62         Wood
# 2474     412421  358402.50  611365.85         Wood
# 36287    437709  359482.50  610030.30         Wood
# 34069    476120  356865.79  623665.79         Wood
# 6012     584847  326592.00  592326.85         Wood
# 22657    640441  354681.00  610388.27         Wood
# 11872    758391  341280.46  634269.73         Wood
# 25467    856215  350161.20  602679.25         Wood
# 20693    870827  348955.20  609223.44         Wood
# 12577    925819  343412.76  594724.62         Wood
# 14054    948662  339359.71  602122.54         Wood
# 3414     969495  357947.10  608309.62         Wood
# 30364    975826  353849.81  607132.67         Wood

# %%
df[df.county.str.contains('[A-Z]', regex=True)][['county']].head()
# Out:
#         county
# 0  CLAY COUNTY
# 1  CLAY COUNTY
# 2  CLAY COUNTY
# 3  CLAY COUNTY
# 4  CLAY COUNTY

# %% [markdown]
# ### Below is the equivalent of using the in clause

# %%
df[['policyID', 'tiv_2011', 'tiv_2012', 'construction']][df.construction.isin(['Steel Frame', 'Reinforced Concrete'])].head()
# Out:
#      policyID     tiv_2011     tiv_2012         construction
# 6      995932   19260000.0   20610000.0  Reinforced Concrete
# 21     671392   13410000.0   11700000.0  Reinforced Concrete
# 199    817283   15390000.0   11790000.0  Reinforced Concrete
# 205    475264   16560000.0   20610000.0  Reinforced Concrete
# 413    407962  129600000.0  120600000.0          Steel Frame

# %% [markdown]
# ### The query method can be used to select certain rows

# %%
df[['policyID', 'tiv_2011', 'tiv_2012', 'construction']].query('tiv_2011 > tiv_2012 and construction == \'Steel Frame\'').head()
# Out:
#       policyID     tiv_2011     tiv_2012 construction
# 413     407962  129600000.0  120600000.0  Steel Frame
# 1773    991007   80820000.0   75330000.0  Steel Frame
# 2861    482151  210600000.0  167400000.0  Steel Frame
# 2864    661386   38250000.0   34380000.0  Steel Frame
# 2895    854635   70470000.0   64800000.0  Steel Frame
