# %% [markdown]
# # Jonathan Halverson
# # Tuesday, August 16, 2017
# # Chapter 1 of Geron

# %% [markdown]
# In 2006, Geoffrey Hinton et al. showed how to train a deep neural network to recognize hand written digits with top accuracy. This was the beginning of deep learning. TensorFlow is a library for training deep NN on distributed systems (GPU). Deep learning can beat other conventional models by a substantial amount for many important problems.

# %% [markdown]
# The first mainstream ML application was the spam filter. OCR before that. Arther Samuel gave a definition of machine learning in 1959.
#
# Rules-based approaches are hard to maintain and probably won't handle all possible cases well. Once a ML model has been trained and proven, one can inspect the inner working and learn about how it works. For instance, a spam filter can be examined to see what is considered spam words versus ham words.
#
# Two unsupervised NN architectures are restricted Boltzmann machines and autoencoders.
#
# Francis Galton introduced the term regression to the mean, referring to tall parents having shorter children. The term then stuck for predicting a continuous variable. The Wisdom of Crowds mentions an observation of his from a fair in around 1901.
#
# Keep in mind the clustering methods are still learning methods (there are just no labels). Visualization algorithms are an example of unsupervised learning because they learn groups and plot them close together, for instance. Association rule learning is part of UL. The idea in that case is to work out relationships such as people who buy a lot of honey and nuts tend to buy hand sanitizer.
#
# Semisupervised learning is a mixture of the two. It's like finding people in a set of photos (it finds the individuals and you name them). Deep belief networks are RBMs stacked on top of one another.
#
# Instance-based vs model-based learning: Logistic regression would be model whereas KNN would be instance based, for example.

# %%
import numpy as np

# %%
help(np.c_)
# Out:
# Help on CClass in module numpy.lib.index_tricks object:
#
# class CClass(AxisConcatenator)
#  |  Translates slice objects to concatenation along the second axis.
#  |
#  |  This is short-hand for ``np.r_['-1,2,0', index expression]``, which is
#  |  useful because of its common occurrence. In particular, arrays will be
#  |  stacked along their last axis after being upgraded to at least 2-D with
#  |  1's post-pended to the shape (column vectors made out of 1-D arrays).
#  |
#  |  For detailed documentation, see `r_`.
#  |
#  |  Examples
#  |  --------
#  |  >>> np.c_[np.array([[1,2,3]]), 0, 0, np.array([[4,5,6]])]
#  |  array([[1, 2, 3, 0, 0, 4, 5, 6]])
#  |
#  |  Method resolution order:
#  |      CClass
#  |      AxisConcatenator
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from AxisConcatenator:
#  |
#  |  __getitem__(self, key)
#  |
#  |  __getslice__(self, i, j)
#  |
#  |  __len__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from AxisConcatenator:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
np.c_[np.array([[1,2,3]]), 0, 0, np.array([[4,5,6]])]
# Out:
# array([[1, 2, 3, 0, 0, 4, 5, 6]])

# %%
np.c_[np.array([[1,2,3]]), np.array([[4,5,6]])]
# Out:
# array([[1, 2, 3, 4, 5, 6]])

# %%
np.array([[1,2,3]]) + np.array([[4,5,6]])
# Out:
# array([[5, 7, 9]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('halverson')

import pandas as pd
import sklearn
from sklearn import linear_model

# %%
gdp = pd.read_csv('geron_life_sat/gdp_per_capita.csv', sep='\t', thousands=',', na_values='n/a', encoding='latin1')
gdp
# Out:
#                                                Country  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                               Angola
# 4                                  Antigua and Barbuda
# 5                                            Argentina
# 6                                              Armenia
# 7                                            Australia
# 8                                              Austria
# 9                                           Azerbaijan
# 10                                         The Bahamas
# 11                                             Bahrain
# 12                                          Bangladesh
# 13                                            Barbados
# 14                                             Belarus
# 15                                             Belgium
# 16                                              Belize
# 17                                               Benin
# 18                                              Bhutan
# 19                                             Bolivia
# 20                              Bosnia and Herzegovina
# 21                                            Botswana
# 22                                              Brazil
# 23                                   Brunei Darussalam
# 24                                            Bulgaria
# 25                                        Burkina Faso
# 26                                             Burundi
# 27                                          Cabo Verde
# 28                                            Cambodia
# 29                                            Cameroon
# ..                                                 ...
# 160                                          Swaziland
# 161                                             Sweden
# 162                                        Switzerland
# 163                                              Syria
# 164                           Taiwan Province of China
# 165                                         Tajikistan
# 166                                           Tanzania
# 167                                           Thailand
# 168                                        Timor-Leste
# 169                                               Togo
# 170                                              Tonga
# 171                                Trinidad and Tobago
# 172                                            Tunisia
# 173                                             Turkey
# 174                                       Turkmenistan
# 175                                             Tuvalu
# 176                                             Uganda
# 177                                            Ukraine
# 178                               United Arab Emirates
# 179                                     United Kingdom
# 180                                      United States
# 181                                            Uruguay
# 182                                         Uzbekistan
# 183                                            Vanuatu
# 184                                          Venezuela
# 185                                            Vietnam
# 186                                              Yemen
# 187                                             Zambia
# 188                                           Zimbabwe
# 189  International Monetary Fund, World Economic Ou...
#
#                                     Subject Descriptor         Units  Scale  \
# 0    Gross domestic product per capita, current prices  U.S. dollars  Units
# 1    Gross domestic product per capita, current prices  U.S. dollars  Units
# 2    Gross domestic product per capita, current prices  U.S. dollars  Units
# 3    Gross domestic product per capita, current prices  U.S. dollars  Units
# 4    Gross domestic product per capita, current prices  U.S. dollars  Units
# 5    Gross domestic product per capita, current prices  U.S. dollars  Units
# 6    Gross domestic product per capita, current prices  U.S. dollars  Units
# 7    Gross domestic product per capita, current prices  U.S. dollars  Units
# 8    Gross domestic product per capita, current prices  U.S. dollars  Units
# 9    Gross domestic product per capita, current prices  U.S. dollars  Units
# 10   Gross domestic product per capita, current prices  U.S. dollars  Units
# 11   Gross domestic product per capita, current prices  U.S. dollars  Units
# 12   Gross domestic product per capita, current prices  U.S. dollars  Units
# 13   Gross domestic product per capita, current prices  U.S. dollars  Units
# 14   Gross domestic product per capita, current prices  U.S. dollars  Units
# 15   Gross domestic product per capita, current prices  U.S. dollars  Units
# 16   Gross domestic product per capita, current prices  U.S. dollars  Units
# 17   Gross domestic product per capita, current prices  U.S. dollars  Units
# 18   Gross domestic product per capita, current prices  U.S. dollars  Units
# 19   Gross domestic product per capita, current prices  U.S. dollars  Units
# 20   Gross domestic product per capita, current prices  U.S. dollars  Units
# 21   Gross domestic product per capita, current prices  U.S. dollars  Units
# 22   Gross domestic product per capita, current prices  U.S. dollars  Units
# 23   Gross domestic product per capita, current prices  U.S. dollars  Units
# 24   Gross domestic product per capita, current prices  U.S. dollars  Units
# 25   Gross domestic product per capita, current prices  U.S. dollars  Units
# 26   Gross domestic product per capita, current prices  U.S. dollars  Units
# 27   Gross domestic product per capita, current prices  U.S. dollars  Units
# 28   Gross domestic product per capita, current prices  U.S. dollars  Units
# 29   Gross domestic product per capita, current prices  U.S. dollars  Units
# ..                                                 ...           ...    ...
# 160  Gross domestic product per capita, current prices  U.S. dollars  Units
# 161  Gross domestic product per capita, current prices  U.S. dollars  Units
# 162  Gross domestic product per capita, current prices  U.S. dollars  Units
# 163  Gross domestic product per capita, current prices  U.S. dollars  Units
# 164  Gross domestic product per capita, current prices  U.S. dollars  Units
# 165  Gross domestic product per capita, current prices  U.S. dollars  Units
# 166  Gross domestic product per capita, current prices  U.S. dollars  Units
# 167  Gross domestic product per capita, current prices  U.S. dollars  Units
# 168  Gross domestic product per capita, current prices  U.S. dollars  Units
# 169  Gross domestic product per capita, current prices  U.S. dollars  Units
# 170  Gross domestic product per capita, current prices  U.S. dollars  Units
# 171  Gross domestic product per capita, current prices  U.S. dollars  Units
# 172  Gross domestic product per capita, current prices  U.S. dollars  Units
# 173  Gross domestic product per capita, current prices  U.S. dollars  Units
# 174  Gross domestic product per capita, current prices  U.S. dollars  Units
# 175  Gross domestic product per capita, current prices  U.S. dollars  Units
# 176  Gross domestic product per capita, current prices  U.S. dollars  Units
# 177  Gross domestic product per capita, current prices  U.S. dollars  Units
# 178  Gross domestic product per capita, current prices  U.S. dollars  Units
# 179  Gross domestic product per capita, current prices  U.S. dollars  Units
# 180  Gross domestic product per capita, current prices  U.S. dollars  Units
# 181  Gross domestic product per capita, current prices  U.S. dollars  Units
# 182  Gross domestic product per capita, current prices  U.S. dollars  Units
# 183  Gross domestic product per capita, current prices  U.S. dollars  Units
# 184  Gross domestic product per capita, current prices  U.S. dollars  Units
# 185  Gross domestic product per capita, current prices  U.S. dollars  Units
# 186  Gross domestic product per capita, current prices  U.S. dollars  Units
# 187  Gross domestic product per capita, current prices  U.S. dollars  Units
# 188  Gross domestic product per capita, current prices  U.S. dollars  Units
# 189                                                NaN           NaN    NaN
#
#                          Country/Series-specific Notes       2015  \
# 0    See notes for:  Gross domestic product, curren...    599.994
# 1    See notes for:  Gross domestic product, curren...   3995.383
# 2    See notes for:  Gross domestic product, curren...   4318.135
# 3    See notes for:  Gross domestic product, curren...   4100.315
# 4    See notes for:  Gross domestic product, curren...  14414.302
# 5    See notes for:  Gross domestic product, curren...  13588.846
# 6    See notes for:  Gross domestic product, curren...   3534.860
# 7    See notes for:  Gross domestic product, curren...  50961.865
# 8    See notes for:  Gross domestic product, curren...  43724.031
# 9    See notes for:  Gross domestic product, curren...   5739.433
# 10   See notes for:  Gross domestic product, curren...  23902.805
# 11   See notes for:  Gross domestic product, curren...  23509.981
# 12   See notes for:  Gross domestic product, curren...   1286.868
# 13   See notes for:  Gross domestic product, curren...  15773.555
# 14   See notes for:  Gross domestic product, curren...   5749.119
# 15   See notes for:  Gross domestic product, curren...  40106.632
# 16   See notes for:  Gross domestic product, curren...   4841.735
# 17   See notes for:  Gross domestic product, curren...    780.063
# 18   See notes for:  Gross domestic product, curren...   2843.402
# 19   See notes for:  Gross domestic product, curren...   2886.231
# 20   See notes for:  Gross domestic product, curren...   4088.212
# 21   See notes for:  Gross domestic product, curren...   6040.957
# 22   See notes for:  Gross domestic product, curren...   8669.998
# 23   See notes for:  Gross domestic product, curren...  28236.640
# 24   See notes for:  Gross domestic product, curren...   6831.661
# 25   See notes for:  Gross domestic product, curren...    614.500
# 26   See notes for:  Gross domestic product, curren...    305.783
# 27   See notes for:  Gross domestic product, curren...   3038.511
# 28   See notes for:  Gross domestic product, curren...   1168.036
# 29   See notes for:  Gross domestic product, curren...   1232.423
# ..                                                 ...        ...
# 160  See notes for:  Gross domestic product, curren...   3139.664
# 161  See notes for:  Gross domestic product, curren...  49866.266
# 162  See notes for:  Gross domestic product, curren...  80675.308
# 163  See notes for:  Gross domestic product, curren...        NaN
# 164  See notes for:  Gross domestic product, curren...  22287.562
# 165  See notes for:  Gross domestic product, curren...    922.072
# 166  See notes for:  Gross domestic product, curren...    941.804
# 167  See notes for:  Gross domestic product, curren...   5742.282
# 168  See notes for:  Gross domestic product, curren...   2244.307
# 169  See notes for:  Gross domestic product, curren...    569.435
# 170  See notes for:  Gross domestic product, curren...   3972.741
# 171  See notes for:  Gross domestic product, curren...  18085.759
# 172  See notes for:  Gross domestic product, curren...   3922.653
# 173  See notes for:  Gross domestic product, curren...   9437.372
# 174  See notes for:  Gross domestic product, curren...   6622.414
# 175  See notes for:  Gross domestic product, curren...   3014.630
# 176  See notes for:  Gross domestic product, curren...    620.213
# 177  See notes for:  Gross domestic product, curren...   2004.918
# 178  See notes for:  Gross domestic product, curren...  36060.015
# 179  See notes for:  Gross domestic product, curren...  43770.688
# 180  See notes for:  Gross domestic product, curren...  55805.204
# 181  See notes for:  Gross domestic product, curren...  15748.192
# 182  See notes for:  Gross domestic product, curren...   2120.778
# 183  See notes for:  Gross domestic product, curren...   2847.113
# 184  See notes for:  Gross domestic product, curren...   7744.746
# 185  See notes for:  Gross domestic product, curren...   2088.344
# 186  See notes for:  Gross domestic product, curren...   1302.940
# 187  See notes for:  Gross domestic product, curren...   1350.151
# 188  See notes for:  Gross domestic product, curren...   1064.350
# 189                                                NaN        NaN
#
#      Estimates Start After
# 0                   2013.0
# 1                   2010.0
# 2                   2014.0
# 3                   2014.0
# 4                   2011.0
# 5                   2013.0
# 6                   2014.0
# 7                   2014.0
# 8                   2015.0
# 9                   2014.0
# 10                  2013.0
# 11                  2014.0
# 12                  2013.0
# 13                  2010.0
# 14                  2013.0
# 15                  2014.0
# 16                  2013.0
# 17                  2011.0
# 18                  2011.0
# 19                  2012.0
# 20                  2014.0
# 21                  2008.0
# 22                  2014.0
# 23                  2013.0
# 24                  2014.0
# 25                  2012.0
# 26                     0.0
# 27                  2014.0
# 28                  2012.0
# 29                  2010.0
# ..                     ...
# 160                 2014.0
# 161                 2014.0
# 162                 2015.0
# 163                 2010.0
# 164                 2015.0
# 165                 2014.0
# 166                 2012.0
# 167                 2014.0
# 168                 2011.0
# 169                 2010.0
# 170                 2012.0
# 171                 2012.0
# 172                 2010.0
# 173                 2013.0
# 174                 2004.0
# 175                 2012.0
# 176                 2014.0
# 177                 2015.0
# 178                 2010.0
# 179                 2015.0
# 180                 2015.0
# 181                 2014.0
# 182                 2013.0
# 183                 2014.0
# 184                 2010.0
# 185                 2012.0
# 186                 2008.0
# 187                 2010.0
# 188                 2012.0
# 189                    NaN
#
# [190 rows x 7 columns]

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 7 columns):
# Country                          190 non-null object
# Subject Descriptor               189 non-null object
# Units                            189 non-null object
# Scale                            189 non-null object
# Country/Series-specific Notes    188 non-null object
# 2015                             187 non-null float64
# Estimates Start After            188 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 10.5+ KB

# %%
lifsat = pd.read_csv('geron_life_sat/oecd_bli_2015.csv', header=0)
lifsat
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   HO_BASE
# 1         AUT          Austria   HO_BASE
# 2         BEL          Belgium   HO_BASE
# 3         CAN           Canada   HO_BASE
# 4         CZE   Czech Republic   HO_BASE
# 5         DNK          Denmark   HO_BASE
# 6         FIN          Finland   HO_BASE
# 7         FRA           France   HO_BASE
# 8         DEU          Germany   HO_BASE
# 9         GRC           Greece   HO_BASE
# 10        HUN          Hungary   HO_BASE
# 11        ISL          Iceland   HO_BASE
# 12        IRL          Ireland   HO_BASE
# 13        ITA            Italy   HO_BASE
# 14        JPN            Japan   HO_BASE
# 15        KOR            Korea   HO_BASE
# 16        LUX       Luxembourg   HO_BASE
# 17        MEX           Mexico   HO_BASE
# 18        NLD      Netherlands   HO_BASE
# 19        NZL      New Zealand   HO_BASE
# 20        NOR           Norway   HO_BASE
# 21        POL           Poland   HO_BASE
# 22        PRT         Portugal   HO_BASE
# 23        SVK  Slovak Republic   HO_BASE
# 24        ESP            Spain   HO_BASE
# 25        SWE           Sweden   HO_BASE
# 26        CHE      Switzerland   HO_BASE
# 27        TUR           Turkey   HO_BASE
# 28        GBR   United Kingdom   HO_BASE
# 29        USA    United States   HO_BASE
# ...       ...              ...       ...
# 3262      FRA           France   WL_TNOW
# 3263      DEU          Germany   WL_TNOW
# 3264      GRC           Greece   WL_TNOW
# 3265      HUN          Hungary   WL_TNOW
# 3266      ISL          Iceland   WL_TNOW
# 3267      IRL          Ireland   WL_TNOW
# 3268      ITA            Italy   WL_TNOW
# 3269      JPN            Japan   WL_TNOW
# 3270      KOR            Korea   WL_TNOW
# 3271      LUX       Luxembourg   WL_TNOW
# 3272      MEX           Mexico   WL_TNOW
# 3273      NLD      Netherlands   WL_TNOW
# 3274      NZL      New Zealand   WL_TNOW
# 3275      NOR           Norway   WL_TNOW
# 3276      POL           Poland   WL_TNOW
# 3277      PRT         Portugal   WL_TNOW
# 3278      SVK  Slovak Republic   WL_TNOW
# 3279      ESP            Spain   WL_TNOW
# 3280      SWE           Sweden   WL_TNOW
# 3281      CHE      Switzerland   WL_TNOW
# 3282      TUR           Turkey   WL_TNOW
# 3283      GBR   United Kingdom   WL_TNOW
# 3284      USA    United States   WL_TNOW
# 3285      BRA           Brazil   WL_TNOW
# 3286      CHL            Chile   WL_TNOW
# 3287      EST          Estonia   WL_TNOW
# 3288      ISR           Israel   WL_TNOW
# 3289      RUS           Russia   WL_TNOW
# 3290      SVN         Slovenia   WL_TNOW
# 3291     OECD     OECD - Total   WL_TNOW
#
#                                       Indicator MEASURE Measure INEQUALITY  \
# 0            Dwellings without basic facilities       L   Value        TOT
# 1            Dwellings without basic facilities       L   Value        TOT
# 2            Dwellings without basic facilities       L   Value        TOT
# 3            Dwellings without basic facilities       L   Value        TOT
# 4            Dwellings without basic facilities       L   Value        TOT
# 5            Dwellings without basic facilities       L   Value        TOT
# 6            Dwellings without basic facilities       L   Value        TOT
# 7            Dwellings without basic facilities       L   Value        TOT
# 8            Dwellings without basic facilities       L   Value        TOT
# 9            Dwellings without basic facilities       L   Value        TOT
# 10           Dwellings without basic facilities       L   Value        TOT
# 11           Dwellings without basic facilities       L   Value        TOT
# 12           Dwellings without basic facilities       L   Value        TOT
# 13           Dwellings without basic facilities       L   Value        TOT
# 14           Dwellings without basic facilities       L   Value        TOT
# 15           Dwellings without basic facilities       L   Value        TOT
# 16           Dwellings without basic facilities       L   Value        TOT
# 17           Dwellings without basic facilities       L   Value        TOT
# 18           Dwellings without basic facilities       L   Value        TOT
# 19           Dwellings without basic facilities       L   Value        TOT
# 20           Dwellings without basic facilities       L   Value        TOT
# 21           Dwellings without basic facilities       L   Value        TOT
# 22           Dwellings without basic facilities       L   Value        TOT
# 23           Dwellings without basic facilities       L   Value        TOT
# 24           Dwellings without basic facilities       L   Value        TOT
# 25           Dwellings without basic facilities       L   Value        TOT
# 26           Dwellings without basic facilities       L   Value        TOT
# 27           Dwellings without basic facilities       L   Value        TOT
# 28           Dwellings without basic facilities       L   Value        TOT
# 29           Dwellings without basic facilities       L   Value        TOT
# ...                                         ...     ...     ...        ...
# 3262  Time devoted to leisure and personal care       L   Value        WMN
# 3263  Time devoted to leisure and personal care       L   Value        WMN
# 3264  Time devoted to leisure and personal care       L   Value        WMN
# 3265  Time devoted to leisure and personal care       L   Value        WMN
# 3266  Time devoted to leisure and personal care       L   Value        WMN
# 3267  Time devoted to leisure and personal care       L   Value        WMN
# 3268  Time devoted to leisure and personal care       L   Value        WMN
# 3269  Time devoted to leisure and personal care       L   Value        WMN
# 3270  Time devoted to leisure and personal care       L   Value        WMN
# 3271  Time devoted to leisure and personal care       L   Value        WMN
# 3272  Time devoted to leisure and personal care       L   Value        WMN
# 3273  Time devoted to leisure and personal care       L   Value        WMN
# 3274  Time devoted to leisure and personal care       L   Value        WMN
# 3275  Time devoted to leisure and personal care       L   Value        WMN
# 3276  Time devoted to leisure and personal care       L   Value        WMN
# 3277  Time devoted to leisure and personal care       L   Value        WMN
# 3278  Time devoted to leisure and personal care       L   Value        WMN
# 3279  Time devoted to leisure and personal care       L   Value        WMN
# 3280  Time devoted to leisure and personal care       L   Value        WMN
# 3281  Time devoted to leisure and personal care       L   Value        WMN
# 3282  Time devoted to leisure and personal care       L   Value        WMN
# 3283  Time devoted to leisure and personal care       L   Value        WMN
# 3284  Time devoted to leisure and personal care       L   Value        WMN
# 3285  Time devoted to leisure and personal care       L   Value        WMN
# 3286  Time devoted to leisure and personal care       L   Value        WMN
# 3287  Time devoted to leisure and personal care       L   Value        WMN
# 3288  Time devoted to leisure and personal care       L   Value        WMN
# 3289  Time devoted to leisure and personal care       L   Value        WMN
# 3290  Time devoted to leisure and personal care       L   Value        WMN
# 3291  Time devoted to leisure and personal care       L   Value        WMN
#
#      Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 0         Total        PC  Percentage               0     units
# 1         Total        PC  Percentage               0     units
# 2         Total        PC  Percentage               0     units
# 3         Total        PC  Percentage               0     units
# 4         Total        PC  Percentage               0     units
# 5         Total        PC  Percentage               0     units
# 6         Total        PC  Percentage               0     units
# 7         Total        PC  Percentage               0     units
# 8         Total        PC  Percentage               0     units
# 9         Total        PC  Percentage               0     units
# 10        Total        PC  Percentage               0     units
# 11        Total        PC  Percentage               0     units
# 12        Total        PC  Percentage               0     units
# 13        Total        PC  Percentage               0     units
# 14        Total        PC  Percentage               0     units
# 15        Total        PC  Percentage               0     units
# 16        Total        PC  Percentage               0     units
# 17        Total        PC  Percentage               0     units
# 18        Total        PC  Percentage               0     units
# 19        Total        PC  Percentage               0     units
# 20        Total        PC  Percentage               0     units
# 21        Total        PC  Percentage               0     units
# 22        Total        PC  Percentage               0     units
# 23        Total        PC  Percentage               0     units
# 24        Total        PC  Percentage               0     units
# 25        Total        PC  Percentage               0     units
# 26        Total        PC  Percentage               0     units
# 27        Total        PC  Percentage               0     units
# 28        Total        PC  Percentage               0     units
# 29        Total        PC  Percentage               0     units
# ...         ...       ...         ...             ...       ...
# 3262      Women      HOUR       Hours               0     units
# 3263      Women      HOUR       Hours               0     units
# 3264      Women      HOUR       Hours               0     units
# 3265      Women      HOUR       Hours               0     units
# 3266      Women      HOUR       Hours               0     units
# 3267      Women      HOUR       Hours               0     units
# 3268      Women      HOUR       Hours               0     units
# 3269      Women      HOUR       Hours               0     units
# 3270      Women      HOUR       Hours               0     units
# 3271      Women      HOUR       Hours               0     units
# 3272      Women      HOUR       Hours               0     units
# 3273      Women      HOUR       Hours               0     units
# 3274      Women      HOUR       Hours               0     units
# 3275      Women      HOUR       Hours               0     units
# 3276      Women      HOUR       Hours               0     units
# 3277      Women      HOUR       Hours               0     units
# 3278      Women      HOUR       Hours               0     units
# 3279      Women      HOUR       Hours               0     units
# 3280      Women      HOUR       Hours               0     units
# 3281      Women      HOUR       Hours               0     units
# 3282      Women      HOUR       Hours               0     units
# 3283      Women      HOUR       Hours               0     units
# 3284      Women      HOUR       Hours               0     units
# 3285      Women      HOUR       Hours               0     units
# 3286      Women      HOUR       Hours               0     units
# 3287      Women      HOUR       Hours               0     units
# 3288      Women      HOUR       Hours               0     units
# 3289      Women      HOUR       Hours               0     units
# 3290      Women      HOUR       Hours               0     units
# 3291      Women      HOUR       Hours               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes  \
# 0                       NaN               NaN   1.10          E
# 1                       NaN               NaN   1.00        NaN
# 2                       NaN               NaN   2.00        NaN
# 3                       NaN               NaN   0.20        NaN
# 4                       NaN               NaN   0.90        NaN
# 5                       NaN               NaN   0.90        NaN
# 6                       NaN               NaN   0.60        NaN
# 7                       NaN               NaN   0.50        NaN
# 8                       NaN               NaN   0.10        NaN
# 9                       NaN               NaN   0.70        NaN
# 10                      NaN               NaN   4.80        NaN
# 11                      NaN               NaN   0.40        NaN
# 12                      NaN               NaN   0.20        NaN
# 13                      NaN               NaN   1.10        NaN
# 14                      NaN               NaN   6.40        NaN
# 15                      NaN               NaN   4.20        NaN
# 16                      NaN               NaN   0.10        NaN
# 17                      NaN               NaN   4.20        NaN
# 18                      NaN               NaN   0.00        NaN
# 19                      NaN               NaN   0.20          E
# 20                      NaN               NaN   0.30        NaN
# 21                      NaN               NaN   3.20        NaN
# 22                      NaN               NaN   0.90        NaN
# 23                      NaN               NaN   0.60        NaN
# 24                      NaN               NaN   0.10        NaN
# 25                      NaN               NaN   0.00        NaN
# 26                      NaN               NaN   0.00        NaN
# 27                      NaN               NaN  12.70        NaN
# 28                      NaN               NaN   0.20        NaN
# 29                      NaN               NaN   0.10        NaN
# ...                     ...               ...    ...        ...
# 3262                    NaN               NaN  14.90        NaN
# 3263                    NaN               NaN  15.31        NaN
# 3264                    NaN               NaN  14.69          E
# 3265                    NaN               NaN  14.82          E
# 3266                    NaN               NaN  14.37          E
# 3267                    NaN               NaN  14.97          E
# 3268                    NaN               NaN  14.32        NaN
# 3269                    NaN               NaN  14.88        NaN
# 3270                    NaN               NaN  14.07        NaN
# 3271                    NaN               NaN  14.90          E
# 3272                    NaN               NaN  13.63          E
# 3273                    NaN               NaN  15.23          E
# 3274                    NaN               NaN  14.93        NaN
# 3275                    NaN               NaN  15.67        NaN
# 3276                    NaN               NaN  13.83        NaN
# 3277                    NaN               NaN  14.72          E
# 3278                    NaN               NaN  14.76          E
# 3279                    NaN               NaN  15.52        NaN
# 3280                    NaN               NaN  15.30        NaN
# 3281                    NaN               NaN  14.76          E
# 3282                    NaN               NaN  13.13          E
# 3283                    NaN               NaN  14.60        NaN
# 3284                    NaN               NaN  14.12        NaN
# 3285                    NaN               NaN  14.75          E
# 3286                    NaN               NaN  14.16          E
# 3287                    NaN               NaN  14.43        NaN
# 3288                    NaN               NaN  14.24          E
# 3289                    NaN               NaN  14.75          E
# 3290                    NaN               NaN  14.12        NaN
# 3291                    NaN               NaN  14.74        NaN
#
#                 Flags
# 0     Estimated value
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19    Estimated value
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ...               ...
# 3262              NaN
# 3263              NaN
# 3264  Estimated value
# 3265  Estimated value
# 3266  Estimated value
# 3267  Estimated value
# 3268              NaN
# 3269              NaN
# 3270              NaN
# 3271  Estimated value
# 3272  Estimated value
# 3273  Estimated value
# 3274              NaN
# 3275              NaN
# 3276              NaN
# 3277  Estimated value
# 3278  Estimated value
# 3279              NaN
# 3280              NaN
# 3281  Estimated value
# 3282  Estimated value
# 3283              NaN
# 3284              NaN
# 3285  Estimated value
# 3286  Estimated value
# 3287              NaN
# 3288  Estimated value
# 3289  Estimated value
# 3290              NaN
# 3291              NaN
#
# [3292 rows x 17 columns]

# %%
lifsat.Indicator.value_counts().sort_index()
# Out:
# Air pollution                                109
# Assault rate                                 111
# Consultation on rule-making                  109
# Dwellings without basic facilities           109
# Educational attainment                       111
# Employees working very long hours            111
# Employment rate                              185
# Homicide rate                                111
# Household net adjusted disposable income     183
# Household net financial wealth               109
# Housing expenditure                          109
# Job security                                 111
# Life expectancy                              111
# Life satisfaction                            179
# Long-term unemployment rate                  185
# Personal earnings                            185
# Quality of support network                   167
# Rooms per person                             109
# Self-reported health                         185
# Student skills                               185
# Time devoted to leisure and personal care    111
# Voter turnout                                185
# Water quality                                111
# Years in education                           111
# Name: Indicator, dtype: int64

# %%
ls = lifsat[lifsat.Indicator == 'Life satisfaction']
ls
# Out:
#      LOCATION          Country INDICATOR          Indicator MEASURE Measure  \
# 2669      AUS        Australia   SW_LIFS  Life satisfaction       L   Value
# 2670      AUT          Austria   SW_LIFS  Life satisfaction       L   Value
# 2671      BEL          Belgium   SW_LIFS  Life satisfaction       L   Value
# 2672      CAN           Canada   SW_LIFS  Life satisfaction       L   Value
# 2673      CZE   Czech Republic   SW_LIFS  Life satisfaction       L   Value
# 2674      DNK          Denmark   SW_LIFS  Life satisfaction       L   Value
# 2675      FIN          Finland   SW_LIFS  Life satisfaction       L   Value
# 2676      FRA           France   SW_LIFS  Life satisfaction       L   Value
# 2677      DEU          Germany   SW_LIFS  Life satisfaction       L   Value
# 2678      GRC           Greece   SW_LIFS  Life satisfaction       L   Value
# 2679      HUN          Hungary   SW_LIFS  Life satisfaction       L   Value
# 2680      ISL          Iceland   SW_LIFS  Life satisfaction       L   Value
# 2681      IRL          Ireland   SW_LIFS  Life satisfaction       L   Value
# 2682      ITA            Italy   SW_LIFS  Life satisfaction       L   Value
# 2683      JPN            Japan   SW_LIFS  Life satisfaction       L   Value
# 2684      KOR            Korea   SW_LIFS  Life satisfaction       L   Value
# 2685      LUX       Luxembourg   SW_LIFS  Life satisfaction       L   Value
# 2686      MEX           Mexico   SW_LIFS  Life satisfaction       L   Value
# 2687      NLD      Netherlands   SW_LIFS  Life satisfaction       L   Value
# 2688      NZL      New Zealand   SW_LIFS  Life satisfaction       L   Value
# 2689      NOR           Norway   SW_LIFS  Life satisfaction       L   Value
# 2690      POL           Poland   SW_LIFS  Life satisfaction       L   Value
# 2691      PRT         Portugal   SW_LIFS  Life satisfaction       L   Value
# 2692      SVK  Slovak Republic   SW_LIFS  Life satisfaction       L   Value
# 2693      ESP            Spain   SW_LIFS  Life satisfaction       L   Value
# 2694      SWE           Sweden   SW_LIFS  Life satisfaction       L   Value
# 2695      CHE      Switzerland   SW_LIFS  Life satisfaction       L   Value
# 2696      TUR           Turkey   SW_LIFS  Life satisfaction       L   Value
# 2697      GBR   United Kingdom   SW_LIFS  Life satisfaction       L   Value
# 2698      USA    United States   SW_LIFS  Life satisfaction       L   Value
# ...       ...              ...       ...                ...     ...     ...
# 2818      CAN           Canada   SW_LIFS  Life satisfaction       L   Value
# 2819      CZE   Czech Republic   SW_LIFS  Life satisfaction       L   Value
# 2820      FIN          Finland   SW_LIFS  Life satisfaction       L   Value
# 2821      FRA           France   SW_LIFS  Life satisfaction       L   Value
# 2822      DEU          Germany   SW_LIFS  Life satisfaction       L   Value
# 2823      GRC           Greece   SW_LIFS  Life satisfaction       L   Value
# 2824      HUN          Hungary   SW_LIFS  Life satisfaction       L   Value
# 2825      ISL          Iceland   SW_LIFS  Life satisfaction       L   Value
# 2826      IRL          Ireland   SW_LIFS  Life satisfaction       L   Value
# 2827      ITA            Italy   SW_LIFS  Life satisfaction       L   Value
# 2828      JPN            Japan   SW_LIFS  Life satisfaction       L   Value
# 2829      KOR            Korea   SW_LIFS  Life satisfaction       L   Value
# 2830      LUX       Luxembourg   SW_LIFS  Life satisfaction       L   Value
# 2831      MEX           Mexico   SW_LIFS  Life satisfaction       L   Value
# 2832      NZL      New Zealand   SW_LIFS  Life satisfaction       L   Value
# 2833      NOR           Norway   SW_LIFS  Life satisfaction       L   Value
# 2834      POL           Poland   SW_LIFS  Life satisfaction       L   Value
# 2835      PRT         Portugal   SW_LIFS  Life satisfaction       L   Value
# 2836      SVK  Slovak Republic   SW_LIFS  Life satisfaction       L   Value
# 2837      ESP            Spain   SW_LIFS  Life satisfaction       L   Value
# 2838      SWE           Sweden   SW_LIFS  Life satisfaction       L   Value
# 2839      CHE      Switzerland   SW_LIFS  Life satisfaction       L   Value
# 2840      TUR           Turkey   SW_LIFS  Life satisfaction       L   Value
# 2841      GBR   United Kingdom   SW_LIFS  Life satisfaction       L   Value
# 2842      BRA           Brazil   SW_LIFS  Life satisfaction       L   Value
# 2843      CHL            Chile   SW_LIFS  Life satisfaction       L   Value
# 2844      EST          Estonia   SW_LIFS  Life satisfaction       L   Value
# 2845      RUS           Russia   SW_LIFS  Life satisfaction       L   Value
# 2846      SVN         Slovenia   SW_LIFS  Life satisfaction       L   Value
# 2847     OECD     OECD - Total   SW_LIFS  Life satisfaction       L   Value
#
#      INEQUALITY Inequality Unit Code           Unit  PowerCode Code PowerCode  \
# 2669        TOT      Total   AVSCORE  Average score               0     units
# 2670        TOT      Total   AVSCORE  Average score               0     units
# 2671        TOT      Total   AVSCORE  Average score               0     units
# 2672        TOT      Total   AVSCORE  Average score               0     units
# 2673        TOT      Total   AVSCORE  Average score               0     units
# 2674        TOT      Total   AVSCORE  Average score               0     units
# 2675        TOT      Total   AVSCORE  Average score               0     units
# 2676        TOT      Total   AVSCORE  Average score               0     units
# 2677        TOT      Total   AVSCORE  Average score               0     units
# 2678        TOT      Total   AVSCORE  Average score               0     units
# 2679        TOT      Total   AVSCORE  Average score               0     units
# 2680        TOT      Total   AVSCORE  Average score               0     units
# 2681        TOT      Total   AVSCORE  Average score               0     units
# 2682        TOT      Total   AVSCORE  Average score               0     units
# 2683        TOT      Total   AVSCORE  Average score               0     units
# 2684        TOT      Total   AVSCORE  Average score               0     units
# 2685        TOT      Total   AVSCORE  Average score               0     units
# 2686        TOT      Total   AVSCORE  Average score               0     units
# 2687        TOT      Total   AVSCORE  Average score               0     units
# 2688        TOT      Total   AVSCORE  Average score               0     units
# 2689        TOT      Total   AVSCORE  Average score               0     units
# 2690        TOT      Total   AVSCORE  Average score               0     units
# 2691        TOT      Total   AVSCORE  Average score               0     units
# 2692        TOT      Total   AVSCORE  Average score               0     units
# 2693        TOT      Total   AVSCORE  Average score               0     units
# 2694        TOT      Total   AVSCORE  Average score               0     units
# 2695        TOT      Total   AVSCORE  Average score               0     units
# 2696        TOT      Total   AVSCORE  Average score               0     units
# 2697        TOT      Total   AVSCORE  Average score               0     units
# 2698        TOT      Total   AVSCORE  Average score               0     units
# ...         ...        ...       ...            ...             ...       ...
# 2818         LW        Low   AVSCORE  Average score               0     units
# 2819         LW        Low   AVSCORE  Average score               0     units
# 2820         LW        Low   AVSCORE  Average score               0     units
# 2821         LW        Low   AVSCORE  Average score               0     units
# 2822         LW        Low   AVSCORE  Average score               0     units
# 2823         LW        Low   AVSCORE  Average score               0     units
# 2824         LW        Low   AVSCORE  Average score               0     units
# 2825         LW        Low   AVSCORE  Average score               0     units
# 2826         LW        Low   AVSCORE  Average score               0     units
# 2827         LW        Low   AVSCORE  Average score               0     units
# 2828         LW        Low   AVSCORE  Average score               0     units
# 2829         LW        Low   AVSCORE  Average score               0     units
# 2830         LW        Low   AVSCORE  Average score               0     units
# 2831         LW        Low   AVSCORE  Average score               0     units
# 2832         LW        Low   AVSCORE  Average score               0     units
# 2833         LW        Low   AVSCORE  Average score               0     units
# 2834         LW        Low   AVSCORE  Average score               0     units
# 2835         LW        Low   AVSCORE  Average score               0     units
# 2836         LW        Low   AVSCORE  Average score               0     units
# 2837         LW        Low   AVSCORE  Average score               0     units
# 2838         LW        Low   AVSCORE  Average score               0     units
# 2839         LW        Low   AVSCORE  Average score               0     units
# 2840         LW        Low   AVSCORE  Average score               0     units
# 2841         LW        Low   AVSCORE  Average score               0     units
# 2842         LW        Low   AVSCORE  Average score               0     units
# 2843         LW        Low   AVSCORE  Average score               0     units
# 2844         LW        Low   AVSCORE  Average score               0     units
# 2845         LW        Low   AVSCORE  Average score               0     units
# 2846         LW        Low   AVSCORE  Average score               0     units
# 2847         LW        Low   AVSCORE  Average score               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes Flags
# 2669                    NaN               NaN    7.3        NaN   NaN
# 2670                    NaN               NaN    6.9        NaN   NaN
# 2671                    NaN               NaN    6.9        NaN   NaN
# 2672                    NaN               NaN    7.3        NaN   NaN
# 2673                    NaN               NaN    6.5        NaN   NaN
# 2674                    NaN               NaN    7.5        NaN   NaN
# 2675                    NaN               NaN    7.4        NaN   NaN
# 2676                    NaN               NaN    6.5        NaN   NaN
# 2677                    NaN               NaN    7.0        NaN   NaN
# 2678                    NaN               NaN    4.8        NaN   NaN
# 2679                    NaN               NaN    4.9        NaN   NaN
# 2680                    NaN               NaN    7.5        NaN   NaN
# 2681                    NaN               NaN    7.0        NaN   NaN
# 2682                    NaN               NaN    6.0        NaN   NaN
# 2683                    NaN               NaN    5.9        NaN   NaN
# 2684                    NaN               NaN    5.8        NaN   NaN
# 2685                    NaN               NaN    6.9        NaN   NaN
# 2686                    NaN               NaN    6.7        NaN   NaN
# 2687                    NaN               NaN    7.3        NaN   NaN
# 2688                    NaN               NaN    7.3        NaN   NaN
# 2689                    NaN               NaN    7.4        NaN   NaN
# 2690                    NaN               NaN    5.8        NaN   NaN
# 2691                    NaN               NaN    5.1        NaN   NaN
# 2692                    NaN               NaN    6.1        NaN   NaN
# 2693                    NaN               NaN    6.5        NaN   NaN
# 2694                    NaN               NaN    7.2        NaN   NaN
# 2695                    NaN               NaN    7.5        NaN   NaN
# 2696                    NaN               NaN    5.6        NaN   NaN
# 2697                    NaN               NaN    6.8        NaN   NaN
# 2698                    NaN               NaN    7.2        NaN   NaN
# ...                     ...               ...    ...        ...   ...
# 2818                    NaN               NaN    6.9        NaN   NaN
# 2819                    NaN               NaN    6.3        NaN   NaN
# 2820                    NaN               NaN    7.0        NaN   NaN
# 2821                    NaN               NaN    6.4        NaN   NaN
# 2822                    NaN               NaN    6.6        NaN   NaN
# 2823                    NaN               NaN    3.5        NaN   NaN
# 2824                    NaN               NaN    4.5        NaN   NaN
# 2825                    NaN               NaN    7.4        NaN   NaN
# 2826                    NaN               NaN    6.8        NaN   NaN
# 2827                    NaN               NaN    5.7        NaN   NaN
# 2828                    NaN               NaN    5.6        NaN   NaN
# 2829                    NaN               NaN    5.0        NaN   NaN
# 2830                    NaN               NaN    6.6        NaN   NaN
# 2831                    NaN               NaN    6.1        NaN   NaN
# 2832                    NaN               NaN    7.1        NaN   NaN
# 2833                    NaN               NaN    7.3        NaN   NaN
# 2834                    NaN               NaN    4.8        NaN   NaN
# 2835                    NaN               NaN    4.5        NaN   NaN
# 2836                    NaN               NaN    5.7        NaN   NaN
# 2837                    NaN               NaN    6.1        NaN   NaN
# 2838                    NaN               NaN    7.0        NaN   NaN
# 2839                    NaN               NaN    7.2        NaN   NaN
# 2840                    NaN               NaN    5.3        NaN   NaN
# 2841                    NaN               NaN    6.3        NaN   NaN
# 2842                    NaN               NaN    6.7        NaN   NaN
# 2843                    NaN               NaN    6.0        NaN   NaN
# 2844                    NaN               NaN    5.1        NaN   NaN
# 2845                    NaN               NaN    5.4        NaN   NaN
# 2846                    NaN               NaN    5.0        NaN   NaN
# 2847                    NaN               NaN    5.9        NaN   NaN
#
# [179 rows x 17 columns]

# %%
cmb = pd.merge(gdp, ls, how='inner', on='Country')
cmb[['Country', 'Value', '2015']]
# Out:
#             Country  Value       2015
# 0         Australia    7.3  50961.865
# 1         Australia    7.2  50961.865
# 2         Australia    7.4  50961.865
# 3         Australia    7.4  50961.865
# 4         Australia    7.2  50961.865
# 5           Austria    6.9  43724.031
# 6           Austria    6.9  43724.031
# 7           Austria    7.0  43724.031
# 8           Austria    7.6  43724.031
# 9           Austria    6.9  43724.031
# 10          Belgium    6.9  40106.632
# 11          Belgium    6.8  40106.632
# 12          Belgium    6.9  40106.632
# 13          Belgium    7.2  40106.632
# 14           Brazil    7.0   8669.998
# 15           Brazil    7.0   8669.998
# 16           Brazil    7.0   8669.998
# 17           Brazil    6.7   8669.998
# 18           Canada    7.3  43331.961
# 19           Canada    7.3  43331.961
# 20           Canada    7.3  43331.961
# 21           Canada    7.6  43331.961
# 22           Canada    6.9  43331.961
# 23            Chile    6.7  13340.905
# 24            Chile    6.7  13340.905
# 25            Chile    6.8  13340.905
# 26            Chile    7.7  13340.905
# 27            Chile    6.0  13340.905
# 28   Czech Republic    6.5  17256.918
# 29   Czech Republic    6.5  17256.918
# ..              ...    ...        ...
# 144        Slovenia    5.0  20732.482
# 145           Spain    6.5  25864.721
# 146           Spain    6.4  25864.721
# 147           Spain    6.5  25864.721
# 148           Spain    7.1  25864.721
# 149           Spain    6.1  25864.721
# 150          Sweden    7.2  49866.266
# 151          Sweden    7.2  49866.266
# 152          Sweden    7.2  49866.266
# 153          Sweden    7.5  49866.266
# 154          Sweden    7.0  49866.266
# 155     Switzerland    7.5  80675.308
# 156     Switzerland    7.5  80675.308
# 157     Switzerland    7.5  80675.308
# 158     Switzerland    7.8  80675.308
# 159     Switzerland    7.2  80675.308
# 160          Turkey    5.6   9437.372
# 161          Turkey    5.4   9437.372
# 162          Turkey    5.8   9437.372
# 163          Turkey    6.1   9437.372
# 164          Turkey    5.3   9437.372
# 165  United Kingdom    6.8  43770.688
# 166  United Kingdom    6.8  43770.688
# 167  United Kingdom    6.8  43770.688
# 168  United Kingdom    7.1  43770.688
# 169  United Kingdom    6.3  43770.688
# 170   United States    7.2  55805.204
# 171   United States    7.1  55805.204
# 172   United States    7.2  55805.204
# 173   United States    7.5  55805.204
#
# [174 rows x 3 columns]

# %%
plt.scatter(cmb['2015'], cmb.Value)
plt.xlabel('GDP')
plt.ylabel('Life satisfaction')

# %%
cmb.plot(kind='scatter', x='2015', y='Value')

# %%
model = sklearn.linear_model.LinearRegression()
model.fit(cmb['2015'].values.reshape(-1, 1), cmb.Value)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.predict([[55000.0]])
# Out:
# array([ 7.0378711])

# %%
model.coef_, model.intercept_
# Out:
# (array([  2.44802545e-05]), 5.6914570997516831)

# %%
from sklearn import neighbors

model = sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)
model.fit(cmb['2015'].values.reshape(-1, 1), cmb.Value)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#           weights='uniform')

# %%
model.predict([[55000.0]])
# Out:
# array([ 7.16666667])

# %% [markdown]
# Geron lists the main challenges of machine learning as insufficient quantity of training data, nonrepresentative training data, poor-quality data, irrelevant features, over- and under-fitting the training data. Just by adding data the same model can perform much better (e.g., grammar checker).
