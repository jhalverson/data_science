# %% [markdown]
# # Jonathan Halverson
# # Keeping it Fresh: Predict Restaurant Inspections
# ## Part 8: Model based on categories and neighborhoods

# %% [markdown]
# Here we formulate a simple time-independent model based on the business categories and neighborhoods.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('halverson')

# %% [markdown]
# ### Load the training data:

# %%
df_vio = pd.read_csv('data/training_labels.txt', parse_dates=['date'])
df_vio.rename(columns={'date':'inspect_date'}, inplace=True)
df_vio.head()
# Out:
#       id inspect_date restaurant_id  *  **  ***
# 0    589   2010-02-02      KAoKWjog  3   0    1
# 1  28589   2009-12-10      p038M4om  2   0    0
# 2  31170   2008-07-16      B1oXymOV  4   0    0
# 3   2600   2015-01-30      m0oWJl3G  1   0    3
# 4   1016   2012-03-19      rJoQwlEV  0   0    0

# %% [markdown]
# ### Clean the training data by removing duplicate inspections

# %%
from helper_methods import drop_duplicate_inspections
df_vio = df_vio.sort_values(['restaurant_id', 'inspect_date'])
df_vio = drop_duplicate_inspections(df_vio, threshold=60)
df_vio.head()
# Out:
#           id inspect_date restaurant_id  *  **  ***
# 1801   28144   2007-09-21      0ZED0WED  3   1    0
# 551    24765   2008-03-26      0ZED0WED  3   1    0
# 5460   25193   2008-10-08      0ZED0WED  6   2    4
# 3641   12775   2009-03-03      0ZED0WED  3   0    0
# 18452  25850   2009-07-23      0ZED0WED  1   0    2

# %% [markdown]
# ### Load the data to relate restaurant id to business id

# %%
trans = pd.read_csv('data/restaurant_ids_to_yelp_ids.csv')
trans = trans[trans['yelp_id_1'].isnull()]
trans.drop(['yelp_id_1', 'yelp_id_2', 'yelp_id_3'], axis=1, inplace=True)
trans.columns = ['restaurant_id', 'business_id']
trans.head()
# Out:
#   restaurant_id             business_id
# 0      Y1Em4GOw  5Kdf1DGbRScRk6Cx3jaX8w
# 1      KAoKP6Og  Urw6NASrebP6tyFdjwjkwQ
# 2      WeEe7eoa  xlOE7jqbW1Q_PrvLBVlegQ
# 3      V430mqoB  ktYpqtygWIJ2RjVPGTxNaA
# 4      ekE4Qz32  n8CsQy7Iy1IMhP85hPVKPA

# %%
df_trans = pd.merge(trans, df_vio, on='restaurant_id', how='inner')
df_trans.head()
# Out:
#   restaurant_id             business_id     id inspect_date  *  **  ***
# 0      Y1Em4GOw  5Kdf1DGbRScRk6Cx3jaX8w     17   2015-02-06  1   0    0
# 1      KAoKP6Og  Urw6NASrebP6tyFdjwjkwQ   9337   2007-06-27  0   0    0
# 2      KAoKP6Og  Urw6NASrebP6tyFdjwjkwQ   5052   2008-03-25  8   0    0
# 3      KAoKP6Og  Urw6NASrebP6tyFdjwjkwQ  12585   2009-04-23  5   0    2
# 4      KAoKP6Og  Urw6NASrebP6tyFdjwjkwQ   3583   2010-03-25  4   0    0

# %% [markdown]
# ### Load the business data

# %%
from helper_methods import read_json

df_biz = read_json('data/yelp_academic_dataset_business.json')
df_biz.head(2).transpose()
# Out:
#                                                                0  \
# attributes     {u'Price Range': 1, u'Accepts Credit Cards': T...
# business_id                               Jp9svt7sRT4zwdbzQ8KQmw
# categories     [Bakeries, Food, Event Planning & Services, Ca...
# city                                                      Boston
# full_address   75 Federal Street\nFinancial District\nBoston,...
# hours                                                         {}
# latitude                                                 42.3551
# longitude                                               -71.0565
# name                                              Rebecca's Cafe
# neighborhoods                               [Financial District]
# open                                                       False
# review_count                                                   6
# stars                                                        3.5
# state                                                         MA
# type                                                    business
#
#                                                                1
# attributes     {u'Take-out': True, u'Price Range': 1, u'Outdo...
# business_id                               CgdK8DiyX9Y4kTKEPi_qgA
# categories     [Delis, Restaurants, Event Planning & Services...
# city                                                      Boston
# full_address      8 City Hall Ave\nBeacon Hill\nBoston, MA 02108
# hours          {u'Tuesday': {u'close': u'15:00', u'open': u'0...
# latitude                                                 42.3575
# longitude                                               -71.0691
# name                                     Delicato Cafe & Caterer
# neighborhoods                                      [Beacon Hill]
# open                                                       False
# review_count                                                  44
# stars                                                          4
# state                                                         MA
# type                                                    business

# %% [markdown]
# ### Add the neighborhoods as features

# %%
neighborhoods = list(set(df_biz['neighborhoods'].sum()))
for neighborhood in neighborhoods:
    df_biz[neighborhood] = df_biz.neighborhoods.apply(lambda x: 1 if neighborhood in x else 0)
df_biz['Other'] = df_biz.neighborhoods.apply(lambda x: 1 if x == [] else 0)
neighborhoods += ['Other']
df_biz[['neighborhoods'] + neighborhoods].head(5).transpose()
# Out:
#                                         0              1           2  \
# neighborhoods        [Financial District]  [Beacon Hill]  [Downtown]
# Roslindale Village                      0              0           0
# Fenway                                  0              0           0
# Financial District                      1              0           0
# East Boston                             0              0           0
# Hyde Park                               0              0           0
# West Roxbury                            0              0           0
# Fields Corner                           0              0           0
# Mission Hill                            0              0           0
# Allston/Brighton                        0              0           0
# Egleston Square                         0              0           0
# Dorchester                              0              0           0
# Mattapan                                0              0           0
# South End                               0              0           0
# Downtown                                0              0           1
# Central Square                          0              0           0
# North End                               0              0           0
# Waterfront                              0              0           0
# Back Bay                                0              0           0
# Charlestown                             0              0           0
# West Roxbury Center                     0              0           0
# Chinatown                               0              0           0
# Beacon Hill                             0              1           0
# Dudley Square                           0              0           0
# Roslindale                              0              0           0
# South Boston                            0              0           0
# Leather District                        0              0           0
# Uphams Corner                           0              0           0
# Jamaica Plain                           0              0           0
# Other                                   0              0           0
#
#                                            3           4
# neighborhoods        [Beacon Hill, Downtown]  [Downtown]
# Roslindale Village                         0           0
# Fenway                                     0           0
# Financial District                         0           0
# East Boston                                0           0
# Hyde Park                                  0           0
# West Roxbury                               0           0
# Fields Corner                              0           0
# Mission Hill                               0           0
# Allston/Brighton                           0           0
# Egleston Square                            0           0
# Dorchester                                 0           0
# Mattapan                                   0           0
# South End                                  0           0
# Downtown                                   1           1
# Central Square                             0           0
# North End                                  0           0
# Waterfront                                 0           0
# Back Bay                                   0           0
# Charlestown                                0           0
# West Roxbury Center                        0           0
# Chinatown                                  0           0
# Beacon Hill                                1           0
# Dudley Square                              0           0
# Roslindale                                 0           0
# South Boston                               0           0
# Leather District                           0           0
# Uphams Corner                              0           0
# Jamaica Plain                              0           0
# Other                                      0           0

# %%
# it was necessary to add Other so that each restaurant was assigned
df_biz[neighborhoods].sum(axis=0).sort_index()
# Out:
# Allston/Brighton       152
# Back Bay               216
# Beacon Hill             52
# Central Square           1
# Charlestown             31
# Chinatown               75
# Dorchester              94
# Downtown               123
# Dudley Square           11
# East Boston             88
# Egleston Square          2
# Fenway                  52
# Fields Corner            5
# Financial District      93
# Hyde Park                8
# Jamaica Plain           71
# Leather District        15
# Mattapan                 7
# Mission Hill            13
# North End              103
# Other                  417
# Roslindale              40
# Roslindale Village      19
# South Boston           149
# South End               96
# Uphams Corner            5
# Waterfront              85
# West Roxbury            40
# West Roxbury Center     21
# dtype: int64

# %%
# every restaurant is assigned to at least 1 neighborhood which may be Other
df_biz[neighborhoods].sum(axis=1).value_counts()
# Out:
# 1    1793
# 2     120
# 3      17
# dtype: int64

# %% [markdown]
# ### Add the categories as features

# %%
categories = list(set(df_biz['categories'].sum()))
for category in categories:
    df_biz[category] = df_biz.categories.apply(lambda x: 1 if category in x else 0)
df_biz[['categories'] + categories].head(3).transpose()
# Out:
#                                                                             0  \
# categories                  [Bakeries, Food, Event Planning & Services, Ca...
# Tapas/Small Plates                                                          0
# Fondue                                                                      0
# Buffets                                                                     0
# Gluten-Free                                                                 0
# Arts & Entertainment                                                        0
# Sandwiches                                                                  0
# Austrian                                                                    0
# Creperies                                                                   0
# Sushi Bars                                                                  0
# Belgian                                                                     0
# Tea Rooms                                                                   0
# Dim Sum                                                                     0
# French                                                                      0
# Chocolatiers & Shops                                                        0
# Juice Bars & Smoothies                                                      0
# Restaurants                                                                 0
# Karaoke                                                                     0
# Men's Clothing                                                              0
# Grocery                                                                     0
# Dominican                                                                   0
# Salad                                                                       0
# Educational Services                                                        0
# Gelato                                                                      0
# Bubble Tea                                                                  0
# Food Delivery Services                                                      0
# Nightlife                                                                   0
# Bowling                                                                     0
# Cocktail Bars                                                               0
# Dive Bars                                                                   0
# ...                                                                       ...
# Fast Food                                                                   0
# Venezuelan                                                                  0
# Colombian                                                                   0
# Pizza                                                                       0
# Pool Halls                                                                  0
# Food                                                                        1
# Beer, Wine & Spirits                                                        0
# Himalayan/Nepalese                                                          0
# Venues & Event Spaces                                                       0
# Music Venues                                                                0
# Lebanese                                                                    0
# Ethnic Food                                                                 0
# Specialty Food                                                              0
# Jazz & Blues                                                                0
# Seafood                                                                     0
# British                                                                     0
# Soup                                                                        0
# Convenience Stores                                                          0
# Comfort Food                                                                0
# Portuguese                                                                  0
# Mexican                                                                     0
# Colleges & Universities                                                     0
# Peruvian                                                                    0
# Cheese Shops                                                                0
# Japanese                                                                    0
# Books, Mags, Music & Video                                                  0
# Cambodian                                                                   0
# Hot Dogs                                                                    0
# Spanish                                                                     0
# Soul Food                                                                   0
#
#                                                                             1  \
# categories                  [Delis, Restaurants, Event Planning & Services...
# Tapas/Small Plates                                                          0
# Fondue                                                                      0
# Buffets                                                                     0
# Gluten-Free                                                                 0
# Arts & Entertainment                                                        0
# Sandwiches                                                                  0
# Austrian                                                                    0
# Creperies                                                                   0
# Sushi Bars                                                                  0
# Belgian                                                                     0
# Tea Rooms                                                                   0
# Dim Sum                                                                     0
# French                                                                      0
# Chocolatiers & Shops                                                        0
# Juice Bars & Smoothies                                                      0
# Restaurants                                                                 1
# Karaoke                                                                     0
# Men's Clothing                                                              0
# Grocery                                                                     0
# Dominican                                                                   0
# Salad                                                                       0
# Educational Services                                                        0
# Gelato                                                                      0
# Bubble Tea                                                                  0
# Food Delivery Services                                                      0
# Nightlife                                                                   0
# Bowling                                                                     0
# Cocktail Bars                                                               0
# Dive Bars                                                                   0
# ...                                                                       ...
# Fast Food                                                                   0
# Venezuelan                                                                  0
# Colombian                                                                   0
# Pizza                                                                       0
# Pool Halls                                                                  0
# Food                                                                        0
# Beer, Wine & Spirits                                                        0
# Himalayan/Nepalese                                                          0
# Venues & Event Spaces                                                       0
# Music Venues                                                                0
# Lebanese                                                                    0
# Ethnic Food                                                                 0
# Specialty Food                                                              0
# Jazz & Blues                                                                0
# Seafood                                                                     0
# British                                                                     0
# Soup                                                                        0
# Convenience Stores                                                          0
# Comfort Food                                                                0
# Portuguese                                                                  0
# Mexican                                                                     0
# Colleges & Universities                                                     0
# Peruvian                                                                    0
# Cheese Shops                                                                0
# Japanese                                                                    0
# Books, Mags, Music & Video                                                  0
# Cambodian                                                                   0
# Hot Dogs                                                                    0
# Spanish                                                                     0
# Soul Food                                                                   0
#
#                                                2
# categories                  [Delis, Restaurants]
# Tapas/Small Plates                             0
# Fondue                                         0
# Buffets                                        0
# Gluten-Free                                    0
# Arts & Entertainment                           0
# Sandwiches                                     0
# Austrian                                       0
# Creperies                                      0
# Sushi Bars                                     0
# Belgian                                        0
# Tea Rooms                                      0
# Dim Sum                                        0
# French                                         0
# Chocolatiers & Shops                           0
# Juice Bars & Smoothies                         0
# Restaurants                                    1
# Karaoke                                        0
# Men's Clothing                                 0
# Grocery                                        0
# Dominican                                      0
# Salad                                          0
# Educational Services                           0
# Gelato                                         0
# Bubble Tea                                     0
# Food Delivery Services                         0
# Nightlife                                      0
# Bowling                                        0
# Cocktail Bars                                  0
# Dive Bars                                      0
# ...                                          ...
# Fast Food                                      0
# Venezuelan                                     0
# Colombian                                      0
# Pizza                                          0
# Pool Halls                                     0
# Food                                           0
# Beer, Wine & Spirits                           0
# Himalayan/Nepalese                             0
# Venues & Event Spaces                          0
# Music Venues                                   0
# Lebanese                                       0
# Ethnic Food                                    0
# Specialty Food                                 0
# Jazz & Blues                                   0
# Seafood                                        0
# British                                        0
# Soup                                           0
# Convenience Stores                             0
# Comfort Food                                   0
# Portuguese                                     0
# Mexican                                        0
# Colleges & Universities                        0
# Peruvian                                       0
# Cheese Shops                                   0
# Japanese                                       0
# Books, Mags, Music & Video                     0
# Cambodian                                      0
# Hot Dogs                                       0
# Spanish                                        0
# Soul Food                                      0
#
# [165 rows x 3 columns]

# %%
df_biz[categories].sum(axis=1).value_counts().sort_index()
# Out:
# 1     36
# 2    830
# 3    476
# 4    325
# 5    188
# 6     63
# 7     12
# dtype: int64

# %% [markdown]
# ### Add average violations as a feature

# %%
avg_violations = df_trans.groupby('business_id').agg({'*':np.mean})
avg_violations.columns = ['mean-*']
avg_violations.head(3)
# Out:
#                           mean-*
# business_id
# -2DW8dE1S0eu48ZnfJeAGQ  7.333333
# -2jQG9-gNH3TshkF-hhR0Q  5.400000
# -5ieYfS-fjUyK93b6Vbv-Q  4.066667

# %%
df_biz = pd.merge(avg_violations, df_biz, left_index=True, right_on='business_id', how='inner')
df_biz['mean-*'] = df_biz['mean-*'].apply(lambda x: x / df_biz['mean-*'].max())

# %% [markdown]
# ### Add crime density as a feature

# %%
cd = pd.read_csv('crime_density.csv', names=['crime_density', 'business_id', 'stars'])
df_biz = pd.merge(cd, df_biz, on='business_id', how='inner')

# %% [markdown]
# ### Finally, join the business data with the violation data

# %%
df_cmb = pd.merge(df_trans, df_biz, on='business_id', how='inner')
df_cmb.head(2).transpose()
# Out:
#                                                                             0  \
# restaurant_id                                                        Y1Em4GOw
# business_id                                            5Kdf1DGbRScRk6Cx3jaX8w
# id                                                                         17
# inspect_date                                              2015-02-06 00:00:00
# *                                                                           1
# **                                                                          0
# ***                                                                         0
# crime_density                                                             327
# stars_x                                                                   3.5
# mean-*                                                              0.0526316
# attributes                  {u'Alcohol': u'full_bar', u'Noise Level': u'lo...
# categories                             [Nightlife, Korean, Bars, Restaurants]
# city                                                                  Allston
# full_address                90-92 Harvard Ave\nAllston/Brighton\nAllston, ...
# hours                       {u'Monday': {u'close': u'01:00', u'open': u'17...
# latitude                                                              42.3533
# longitude                                                            -71.1321
# name                                                       Myung Dong 1st Ave
# neighborhoods                                              [Allston/Brighton]
# open                                                                     True
# review_count                                                              178
# stars_y                                                                   3.5
# state                                                                      MA
# type                                                                 business
# Roslindale Village                                                          0
# Fenway                                                                      0
# Financial District                                                          0
# East Boston                                                                 0
# Hyde Park                                                                   0
# West Roxbury                                                                0
# ...                                                                       ...
# Fast Food                                                                   0
# Venezuelan                                                                  0
# Colombian                                                                   0
# Pizza                                                                       0
# Pool Halls                                                                  0
# Food                                                                        0
# Beer, Wine & Spirits                                                        0
# Himalayan/Nepalese                                                          0
# Venues & Event Spaces                                                       0
# Music Venues                                                                0
# Lebanese                                                                    0
# Ethnic Food                                                                 0
# Specialty Food                                                              0
# Jazz & Blues                                                                0
# Seafood                                                                     0
# British                                                                     0
# Soup                                                                        0
# Convenience Stores                                                          0
# Comfort Food                                                                0
# Portuguese                                                                  0
# Mexican                                                                     0
# Colleges & Universities                                                     0
# Peruvian                                                                    0
# Cheese Shops                                                                0
# Japanese                                                                    0
# Books, Mags, Music & Video                                                  0
# Cambodian                                                                   0
# Hot Dogs                                                                    0
# Spanish                                                                     0
# Soul Food                                                                   0
#
#                                                                             1
# restaurant_id                                                        KAoKP6Og
# business_id                                            Urw6NASrebP6tyFdjwjkwQ
# id                                                                       9337
# inspect_date                                              2007-06-27 00:00:00
# *                                                                           0
# **                                                                          0
# ***                                                                         0
# crime_density                                                              17
# stars_x                                                                   2.5
# mean-*                                                               0.178947
# attributes                  {u'Take-out': True, u'Accepts Credit Cards': T...
# categories                               [Fast Food, Sandwiches, Restaurants]
# city                                                                  Allston
# full_address                260 Western Ave\nAllston/Brighton\nAllston, MA...
# hours                       {u'Monday': {u'close': u'22:00', u'open': u'09...
# latitude                                                              42.3629
# longitude                                                            -71.1332
# name                                                                   Subway
# neighborhoods                                              [Allston/Brighton]
# open                                                                     True
# review_count                                                               16
# stars_y                                                                   2.5
# state                                                                      MA
# type                                                                 business
# Roslindale Village                                                          0
# Fenway                                                                      0
# Financial District                                                          0
# East Boston                                                                 0
# Hyde Park                                                                   0
# West Roxbury                                                                0
# ...                                                                       ...
# Fast Food                                                                   1
# Venezuelan                                                                  0
# Colombian                                                                   0
# Pizza                                                                       0
# Pool Halls                                                                  0
# Food                                                                        0
# Beer, Wine & Spirits                                                        0
# Himalayan/Nepalese                                                          0
# Venues & Event Spaces                                                       0
# Music Venues                                                                0
# Lebanese                                                                    0
# Ethnic Food                                                                 0
# Specialty Food                                                              0
# Jazz & Blues                                                                0
# Seafood                                                                     0
# British                                                                     0
# Soup                                                                        0
# Convenience Stores                                                          0
# Comfort Food                                                                0
# Portuguese                                                                  0
# Mexican                                                                     0
# Colleges & Universities                                                     0
# Peruvian                                                                    0
# Cheese Shops                                                                0
# Japanese                                                                    0
# Books, Mags, Music & Video                                                  0
# Cambodian                                                                   0
# Hot Dogs                                                                    0
# Spanish                                                                     0
# Soul Food                                                                   0
#
# [217 rows x 2 columns]

# %% [markdown]
# ### Create a train-test split

# %%
np.random.seed(0)
msk = np.random.rand(df_cmb.shape[0]) < 0.8
df_train = df_cmb[msk]
df_test = df_cmb[~msk]

# %% [markdown]
# Load modules from scikit-learn and create method to compute scores:

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error as mse

def get_scores(train, test, columns):
    X_train = train[columns].values
    y_true_train = train['*'].values

    param_grid = {'alpha':np.logspace(-3, 3, num=15, base=10)}
    gs = GridSearchCV(Lasso(), param_grid, scoring='mean_squared_error', cv=10)
    gs = gs.fit(X_train, y_true_train)

    y_pred_train = gs.predict(X_train)
    y_true_test = test['*'].values
    y_pred_test = gs.predict(df_test[columns].values)

    mse_train = mse(y_true_train, y_pred_train)
    mse_test = mse(y_true_test, y_pred_test)
    
    return 'MSE (train) = %.1f, MSE (test) = %.1f' % (mse_train, mse_test)

# %% [markdown]
# ### Predictive Models

# %%
print get_scores(df_train, df_test, neighborhoods)
# Out:
# MSE (train) = 17.2, MSE (test) = 17.0

# %%
print get_scores(df_train, df_test, categories)
# Out:
# MSE (train) = 16.8, MSE (test) = 16.8

# %%
print get_scores(df_train, df_test, neighborhoods + categories)
# Out:
# MSE (train) = 16.4, MSE (test) = 16.4

# %%
print get_scores(df_train, df_test, ['mean-*'])
# Out:
# MSE (train) = 13.4, MSE (test) = 13.3

# %%
print get_scores(df_train, df_test, ['crime_density'])
# Out:
# MSE (train) = 17.8, MSE (test) = 17.5

# %%
print get_scores(df_train, df_test, ['mean-*', 'crime_density'])
# Out:
# MSE (train) = 13.4, MSE (test) = 13.3
